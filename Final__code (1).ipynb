# %% [markdown]
# Loading dataset

# %%
import pandas as pd
# Load the dataset with ISO-8859-1 encoding
data = pd.read_excel("/content/fix_final.xlsx")
data.head()
# Out:
#                                               source            author  \
# 0  {'id': 'al-jazeera-english', 'name': 'Al Jazee...  Al Jazeera Staff
# 1  {'id': 'al-jazeera-english', 'name': 'Al Jazee...  Al Jazeera Staff
# 2                         {'id': 'rt', 'name': 'RT'}                RT
# 3                         {'id': 'rt', 'name': 'RT'}                RT
# 4               {'id': None, 'name': 'BusinessLine'}               PTI
#
#                                                title  \
# 0  India election 2024: Why isnâ€™t Modiâ€™s BJP ...
# 1  India Lok Sabha election 2024 Phase 4: Who vot...
# 2                  Indian capital heads to the polls
# 3  Trans Democracy: Five transgender candidates i...
# 4  Lok Sabha elections phase 6: Voting underway i...
#
#                                          description  \
# 0  Absence of the prime minister's party from ele...
# 1  People from across 10 states and union territo...
# 2  Delhi goes to the polls as Indiaâ€™s election ...
# 3  Non-binaries existed in Indian mythology and a...
# 4  Voting begins in 58 constituencies across Indi...
#
#                                                  url  \
# 0  https://www.aljazeera.com/news/2024/5/13/india...
# 1  https://www.aljazeera.com/news/2024/5/12/india...
# 2  https://www.rt.com/india/598233-delhi-phase-el...
# 3  https://www.rt.com/india/597965-five-transgend...
# 4  https://www.thehindubusinessline.com/news/elec...
#
#                                           urlToImage           publishedAt  \
# 0  https://www.aljazeera.com/wp-content/uploads/2...  2024-05-13T04:56:59Z
# 1  https://www.aljazeera.com/wp-content/uploads/2...  2024-05-12T05:12:01Z
# 2  https://mf.b37mrtl.ru/files/2024.05/article/66...  2024-05-25T11:51:47Z
# 3  https://mf.b37mrtl.ru/files/2024.05/article/66...  2024-05-22T03:33:39Z
# 4  https://bl-i.thgim.com/public/incoming/utleux/...  2024-05-25T03:41:43Z
#
#                                         full_content  sentiment_score  \
# 0  The absence of the prime ministerâ€™s party fr...           0.9631
# 1  A total of 96 constituencies across 10 states ...           0.5673
# 2  The sixth phase of voting in Indiaâ€™s seven-p...           0.9449
# 3  In the ongoing seven-phase parliamentary elect...           0.9947
# 4  Get businessline apps on\nConnect with us\nTO ...           0.9685
#
#       Senti party
# 0  Positive   PDP
# 1  Positive   BJP
# 2  Positive   BJP
# 3  Positive   BJP
# 4  Positive   BJP

# %% [markdown]
# Overview of dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   source           213 non-null    object
#  1   author           183 non-null    object
#  2   title            213 non-null    object
#  3   description      213 non-null    object
#  4   url              213 non-null    object
#  5   urlToImage       185 non-null    object
#  6   publishedAt      213 non-null    object
#  7   full_content     213 non-null    object
#  8   sentiment_score  211 non-null    float64
#  9   Senti            213 non-null    object
#  10  party            211 non-null    object
# dtypes: float64(1), object(10)
# memory usage: 18.4+ KB

# %% [markdown]
# Checking missing values

# %%
data.isnull().sum()
# Out:
# source              0
# author             30
# title               0
# description         0
# url                 0
# urlToImage         28
# publishedAt         0
# full_content        0
# sentiment_score     2
# Senti               0
# party               2
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(data.isnull(),yticklabels=False,cbar=False)
plt.show()

# %% [markdown]
# Summarizing the Numerical and Categorical Features

# %%
# Summary of numerical features
numerical_summary = data.describe()

# Summary of categorical features
categorical_summary = data.describe(include=['object'])

numerical_summary, categorical_summary
# Out:
# (       sentiment_score
#  count       211.000000
#  mean          0.739115
#  std           0.590863
#  min          -0.997400
#  25%           0.947350
#  50%           0.987900
#  75%           0.997200
#  max           1.000000,
#                                                     source     author  \
#  count                                                 213        183
#  unique                                                 31         60
#  top     {'id': 'the-times-of-india', 'name': 'The Time...  ET Online
#  freq                                                   60         32
#
#                                                      title  \
#  count                                                 213
#  unique                                                156
#  top     Lok Sabha Polls: Former Indian cricket team ca...
#  freq                                                    4
#
#                                                description  \
#  count                                                 213
#  unique                                                160
#  top     Former Indian cricket team captain MS Dhoni ar...
#  freq                                                    4
#
#                                                        url  \
#  count                                                 213
#  unique                                                156
#  top     https://www.theatlantic.com/magazine/archive/2...
#  freq                                                    3
#
#                                                 urlToImage  \
#  count                                                 185
#  unique                                                131
#  top     https://www.aljazeera.com/wp-content/uploads/2...
#  freq                                                    5
#
#                   publishedAt  \
#  count                    213
#  unique                   148
#  top     2024-06-04T16:55:30Z
#  freq                       4
#
#                                               full_content     Senti party
#  count                                                 213       213   211
#  unique                                                164         3    14
#  top     Modi 3.0 Live\nModi 3.0 is here! Familiar face...  Positive   BJP
#  freq                                                    3       180   146  )

# %% [markdown]
# Visualizing the Distribution of the Target Variable

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
ax = sns.countplot(x='Senti', data=data)
plt.title('Distribution of Sentiment Labels')
plt.xlabel('Sentiment Label')
plt.ylabel('Count')

# Adding the count labels on each bar
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.1, height, ha='center', va='center')

plt.show()

# %% [markdown]
# Visualizing the Distribution of Key Features

# %%
# Visualize the distribution of sentiment_score
plt.figure(figsize=(10, 6))
sns.histplot(data['sentiment_score'], bins=30, kde=True)
plt.title('Distribution of Sentiment Scores')
plt.xlabel('Sentiment Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Checking for Class Imbalance in the Target Variable

# %%
# Check for class imbalance
class_counts = data['Senti'].value_counts()
print(class_counts)
classes=data['Senti'].value_counts().index
classes
# Out:
# Senti
# Positive    180
# Negative     22
# Neutral      11
# Name: count, dtype: int64
# Index(['Positive', 'Negative', 'Neutral'], dtype='object', name='Senti')

# %% [markdown]
# piechart

# %%
plt.pie(class_counts.values, labels=classes, autopct='%1.1f%%')
plt.title('Class Distribution')
plt.show()

# %% [markdown]
# Average score for each category

# %%
data.groupby(['Senti'])['sentiment_score'].mean()
# Out:
# Senti
# Negative   -0.890155
# Neutral     0.147611
# Positive    0.967823
# Name: sentiment_score, dtype: float64

# %% [markdown]
# Filling Missing values

# %%
# Fill null values in col1 with user-defined value
data['author'].fillna("NA", inplace=True)

# Fill null values in col2 with user-defined value
data['urlToImage'].fillna("NA", inplace=True)

data['url'].fillna("NA", inplace=True)

data['title'].fillna("NA", inplace=True)

data['publishedAt'].fillna("NA", inplace=True)

# Replace missing values in `sentiment_score` with the mean of the column
data['sentiment_score'].fillna(data['sentiment_score'].mean(), inplace=True)

# Replace missing values in `sentiment_label` with the mode of the column
data['Senti'].fillna(data['Senti'].mode()[0], inplace=True)

# Replace missing values in `party` with the mode of the column
data['party'].fillna(data['party'].mode()[0], inplace=True)

data.dropna(subset=['full_content'], inplace=True)
data.isnull().sum()
# Out:
# source             0
# author             0
# title              0
# description        0
# url                0
# urlToImage         0
# publishedAt        0
# full_content       0
# sentiment_score    0
# Senti              0
# party              0
# dtype: int64

# %% [markdown]
# Importing Libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from imblearn.over_sampling import SMOTE
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.model_selection import cross_val_score

# %%
# Handle missing values (drop rows with missing target or input features)
# data = data.dropna(subset=['Senti', 'title', 'description', 'full_content', 'sentiment_score'])

# %%
# Encode the target variable
label_encoder = LabelEncoder()
data['sentiment_label_encoded'] = label_encoder.fit_transform(data['Senti'])

# %%
print(data[['sentiment_label_encoded', 'sentiment_score']].head(100))
label_counts = data['sentiment_label_encoded'].value_counts()
print(label_counts)
print(data['sentiment_label_encoded'].unique())
# Out:
#     sentiment_label_encoded  sentiment_score
# 0                         2           0.9631
# 1                         2           0.5673
# 2                         2           0.9449
# 3                         2           0.9947
# 4                         2           0.9685
# ..                      ...              ...
# 95                        2           0.9901
# 96                        2           0.9959
# 97                        2           0.9932
# 98                        2           0.9998
# 99                        2           0.9960
#
# [100 rows x 2 columns]
# sentiment_label_encoded
# 2    180
# 0     22
# 1     11
# Name: count, dtype: int64
# [2 1 0]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# %%
# Feature engineering
data['text'] = data['title'] + ' ' + data['description'] + ' ' + data['full_content']

# %%
# Check class distribution
print(data['Senti'].value_counts())

# %%
# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data['text'], data['Senti'], test_size=0.2, random_state=42, stratify=data['Senti'])

# %%
# Text vectorization
vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# %%
# Define classifiers
classifiers = {
    'Logistic Regression': LogisticRegression(class_weight='balanced'),
    'Naive Bayes': MultinomialNB(),
    'SVM': SVC(class_weight='balanced'),
    'Decision Tree': DecisionTreeClassifier(class_weight='balanced'),
    'Random Forest': RandomForestClassifier(class_weight='balanced')
}

# %%
# Train and evaluate classifiers
for name, clf in classifiers.items():
    print(f'Classifier: {name}')
    clf.fit(X_train_tfidf, y_train)
    y_pred = clf.predict(X_test_tfidf)
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred)
    print(f'Accuracy: {accuracy}')
    print(report)
    print('-' * 80)

     # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
    plt.title(f'Confusion Matrix for {clf_name}')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()
    print("-" * 100)
# Out:
# Senti
# Positive    180
# Negative     22
# Neutral      11
# Name: count, dtype: int64
# Classifier: Logistic Regression
# Accuracy: 0.9534883720930233
#               precision    recall  f1-score   support
#
#     Negative       0.80      0.80      0.80         5
#      Neutral       1.00      0.50      0.67         2
#     Positive       0.97      1.00      0.99        36
#
#     accuracy                           0.95        43
#    macro avg       0.92      0.77      0.82        43
# weighted avg       0.95      0.95      0.95        43
#
# --------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Classifier: Naive Bayes
# Accuracy: 0.8372093023255814
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         5
#      Neutral       0.00      0.00      0.00         2
#     Positive       0.84      1.00      0.91        36
#
#     accuracy                           0.84        43
#    macro avg       0.28      0.33      0.30        43
# weighted avg       0.70      0.84      0.76        43
#
# --------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ----------------------------------------------------------------------------------------------------
# Classifier: SVM
# Accuracy: 0.9534883720930233
#               precision    recall  f1-score   support
#
#     Negative       1.00      0.80      0.89         5
#      Neutral       1.00      0.50      0.67         2
#     Positive       0.95      1.00      0.97        36
#
#     accuracy                           0.95        43
#    macro avg       0.98      0.77      0.84        43
# weighted avg       0.96      0.95      0.95        43
#
# --------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Classifier: Decision Tree
# Accuracy: 0.813953488372093
#               precision    recall  f1-score   support
#
#     Negative       0.33      0.20      0.25         5
#      Neutral       0.50      0.50      0.50         2
#     Positive       0.87      0.92      0.89        36
#
#     accuracy                           0.81        43
#    macro avg       0.57      0.54      0.55        43
# weighted avg       0.79      0.81      0.80        43
#
# --------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Classifier: Random Forest
# Accuracy: 0.9069767441860465
#               precision    recall  f1-score   support
#
#     Negative       1.00      0.40      0.57         5
#      Neutral       1.00      0.50      0.67         2
#     Positive       0.90      1.00      0.95        36
#
#     accuracy                           0.91        43
#    macro avg       0.97      0.63      0.73        43
# weighted avg       0.92      0.91      0.89        43
#
# --------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
